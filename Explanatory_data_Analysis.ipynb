# %%
import pandas as pd

# %%
df_2014=pd.read_csv("Opfer_2014.csv",encoding='ISO-8859-1', sep=';')

# %%
print(df_2014.head(10))
# Out:
#   Schluesselzahl der Tat              Straftat  Gemeindeschlüssel  \
# 0                 ------  Straftaten insgesamt            5334002
# 1                 ------  Straftaten insgesamt            5334002
# 2                 ------  Straftaten insgesamt            5334002
# 3                 ------  Straftaten insgesamt            9761000
# 4                 ------  Straftaten insgesamt            9761000
# 5                 ------  Straftaten insgesamt            9761000
# 6                 ------  Straftaten insgesamt            5378004
# 7                 ------  Straftaten insgesamt            5378004
# 8                 ------  Straftaten insgesamt            5378004
# 9                 ------  Straftaten insgesamt           11000000
#
#                Stadt Fallstatus  Opfer insgesamt - Anzahl  \
# 0             Aachen      voll.                      4033
# 1             Aachen      vers.                       327
# 2             Aachen      insg.                      4360
# ...

# %%
print(df_2014.head())
# Out:
#   Schluesselzahl der Tat              Straftat  Gemeindeschlüssel     Stadt  \
# 0                 ------  Straftaten insgesamt            5334002    Aachen
# 1                 ------  Straftaten insgesamt            5334002    Aachen
# 2                 ------  Straftaten insgesamt            5334002    Aachen
# 3                 ------  Straftaten insgesamt            9761000  Augsburg
# 4                 ------  Straftaten insgesamt            9761000  Augsburg
#
#   Fallstatus  Opfer insgesamt - Anzahl  Opfer insgesamt männlich- Anzahl  \
# 0      voll.                      4033                              2377
# 1      vers.                       327                               206
# 2      insg.                      4360                              2583
# 3      voll.                      4599                              2940
# 4      vers.                       544                               410
#
# ...

# %%
df_2014.columns = df_2014.columns.str.replace(' ', '')

# %%
print(df_2014.head(10))
# Out:
#   SchluesselzahlderTat              Straftat  Gemeindeschlüssel  \
# 0               ------  Straftaten insgesamt            5334002
# 1               ------  Straftaten insgesamt            5334002
# 2               ------  Straftaten insgesamt            5334002
# 3               ------  Straftaten insgesamt            9761000
# 4               ------  Straftaten insgesamt            9761000
# 5               ------  Straftaten insgesamt            9761000
# 6               ------  Straftaten insgesamt            5378004
# 7               ------  Straftaten insgesamt            5378004
# 8               ------  Straftaten insgesamt            5378004
# 9               ------  Straftaten insgesamt           11000000
#
#                Stadt Fallstatus  Opferinsgesamt-Anzahl  \
# 0             Aachen      voll.                   4033
# 1             Aachen      vers.                    327
# 2             Aachen      insg.                   4360
# ...

# %%
df_2014["Jahr"] = 2014
print(df_2014.head())
print(df_2014["Jahr"])
# Out:
#   SchluesselzahlderTat              Straftat  Gemeindeschlüssel     Stadt  \
# 0               ------  Straftaten insgesamt            5334002    Aachen
# 1               ------  Straftaten insgesamt            5334002    Aachen
# 2               ------  Straftaten insgesamt            5334002    Aachen
# 3               ------  Straftaten insgesamt            9761000  Augsburg
# 4               ------  Straftaten insgesamt            9761000  Augsburg
#
#   Fallstatus  Opferinsgesamt-Anzahl  Opferinsgesamtmännlich-Anzahl  \
# 0      voll.                   4033                           2377
# 1      vers.                    327                            206
# 2      insg.                   4360                           2583
# 3      voll.                   4599                           2940
# 4      vers.                    544                            410
#
#    Opferinsgesamtweiblich-Anzahl  Kinderbisunter6Jahre-Anzahl  \
# ...

# %%
df_2015=pd.read_csv("Opfer_2015.csv",encoding='ISO-8859-1', sep=';')
df_2015.columns = df_2015.columns.str.replace(' ', '')
df_2015["Jahr"] = 2015
print(df_2015.head())
print(df_2015["Jahr"])
df_2015= df_2015.iloc[:, :-1]
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#   Opferinsgesamt-Anzahl Opferinsgesamtmaennlich-Anzahl  \
# 0                 3,824                          2,289
# 1                   297                            171
# 2                 4,121                          2,460
# 3                 4,405                          2,758
# 4                   579                            415
#
#   Opferinsgesamtweiblich-Anzahl  Kinderbisunter6Jahre-Anzahl  \
# 0                         1,535                           23
# ...

# %%
df_2016=pd.read_csv("Opfer_2016.csv",encoding='ISO-8859-1', sep=';')
df_2016.columns = df_2016.columns.str.replace(' ', '')
df_2016["Jahr"] = 2016
print(df_2016.head())
print(df_2016["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel              Stadt  \
# 0     ------  Straftaten insgesamt             5334002             Aachen
# 1     ------  Straftaten insgesamt             9761000           Augsburg
# 2     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 3     ------  Straftaten insgesamt            11000000             Berlin
# 4     ------  Straftaten insgesamt             5711000          Bielefeld
#
#   Fallstatus Opferinsgesamt-Anzahl Opferinsgesamtmaennlich-Anzahl  \
# 0      voll.                 4,334                          2,672
# 1      voll.                 4,601                          2,922
# 2      voll.                 1,228                            670
# 3      voll.                71,286                         43,825
# 4      voll.                 4,245                          2,412
#
#   Opferinsgesamtweiblich-Anzahl  Kinderbisunter6Jahre-Anzahl  \
# ...

# %%
df_2017=pd.read_csv("Opfer_2017.csv",encoding='ISO-8859-1', sep=';')
df_2017.columns = df_2017.columns.str.replace(' ', '')
df_2017["Jahr"] = 2017
print(df_2017.head())
print(df_2017["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel              Stadt  \
# 0     ------  Straftaten insgesamt             5334002             Aachen
# 1     ------  Straftaten insgesamt             9761000           Augsburg
# 2     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 3     ------  Straftaten insgesamt            11000000             Berlin
# 4     ------  Straftaten insgesamt             5711000          Bielefeld
#
#   Fallstatus Opferinsgesamt-Anzahl Opferinsgesamtmaennlich-Anzahl  \
# 0      voll.                 4,191                          2,534
# 1      voll.                 4,475                          2,797
# 2      voll.                 1,168                            627
# 3      voll.                71,397                         43,330
# 4      voll.                 4,113                          2,218
#
#   Opferinsgesamtweiblich-Anzahl  Kinderbisunter6Jahre-Anzahl  \
# ...

# %%
df_2018=pd.read_csv("Opfer_2018.csv",encoding='ISO-8859-1', sep=';')
df_2018.columns = df_2018.columns.str.replace(' ', '')
df_2018["Jahr"] = 2018
print(df_2018.head())
print(df_2018["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel              Stadt  \
# 0     ------  Straftaten insgesamt             5334002             Aachen
# 1     ------  Straftaten insgesamt             9761000           Augsburg
# 2     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 3     ------  Straftaten insgesamt            11000000             Berlin
# 4     ------  Straftaten insgesamt             5711000          Bielefeld
#
#   Fallstatus Opferinsgesamt-Anzahl Opferinsgesamtmaennlich-Anzahl  \
# 0      voll.                 4,057                          2,402
# 1      voll.                 4,769                          3,050
# 2      voll.                 1,216                            646
# 3      voll.                74,153                         45,011
# 4      voll.                 4,219                          2,282
#
#   Opferinsgesamtweiblich-Anzahl  Kinderbisunter6Jahre-Anzahl  \
# ...

# %%
df_2019=pd.read_csv("Opfer_2019.csv",encoding='ISO-8859-1', sep=';')
df_2019.columns = df_2019.columns.str.replace(' ', '')
df_2019["Jahr"] = 2019
print(df_2019.head())
print(df_2019["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#   Operinsgesamt Opfermaennlich Opferweiblich  \
# 0         3,828          2,252         1,576
# 1           304            182           122
# 2         4,132          2,434         1,698
# 3         4,879          3,198         1,681
# 4           480            354           126
#
#    Opfer-Kinderbisunter6Jahre-insgesamt  Opfer-Kinderbisunter6Jahre-maennlich  \
# 0                                    23                                    13
# ...

# %%
df_2020=pd.read_csv("Opfer_2020.csv",encoding='ISO-8859-1', sep=';')
df_2020.columns = df_2020.columns.str.replace(' ', '')
df_2020["Jahr"] = 2020
print(df_2020.head())
print(df_2020["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#   Operinsgesamt Opfermaennlich Opferweiblich  \
# 0         3,981          2,335         1,646
# 1           282            168           114
# 2         4,263          2,503         1,760
# 3         4,541          2,874         1,667
# 4           462            327           135
#
#    Opfer-Kinderbisunter6Jahre-insgesamt  Opfer-Kinderbisunter6Jahre-maennlich  \
# 0                                    40                                    22
# ...

# %%
df_2021=pd.read_csv("Opfer_2021.csv",encoding='ISO-8859-1', sep=';')
df_2021.columns = df_2021.columns.str.replace(' ', '')
df_2021["Jahr"] = 2021
print(df_2021.head())
print(df_2021["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#   Operinsgesamt Opfermaennlich Opferweiblich  \
# 0         3,952          2,304         1,648
# 1           345            203           142
# 2         4,297          2,507         1,790
# 3         4,142          2,565         1,577
# 4           477            336           141
#
#    Opfer-Kinderbisunter6Jahre-insgesamt  Opfer-Kinderbisunter6Jahre-maennlich  \
# 0                                    19                                     8
# ...

# %%
df_2022=pd.read_csv("Opfer_2022.csv",encoding='ISO-8859-1', sep=';')
df_2022.columns = df_2022.columns.str.replace(' ', '')
df_2022["Jahr"] = 2022
print(df_2022.head())
print(df_2022["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 1     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      vers.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      voll.
#
#   Operinsgesamt Opfermaennlich Opferweiblich  \
# 0           399            256           143
# 1         4,561          2,659         1,902
# 2         4,960          2,915         2,045
# 3           505            333           172
# 4         5,100          3,221         1,879
#
#    Opfer-Kinderbisunter6Jahre-insgesamt  Opfer-Kinderbisunter6Jahre-maennlich  \
# 0                                     7                                     6
# ...

# %%
df_2023=pd.read_csv("Opfer_2023.csv",encoding='ISO-8859-1', sep=';')
df_2023.columns = df_2023.columns.str.replace(' ', '')
df_2023["Jahr"] = 2023
print(df_2023.head())
print(df_2023["Jahr"])
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 1     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      vers.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      voll.
#
#   Operinsgesamt Opfermaennlich Opferweiblich  \
# 0           436            278           158
# 1         4,595          2,777         1,818
# 2         5,031          3,055         1,976
# 3           561            364           197
# 4         5,654          3,480         2,174
#
#    Opfer-Kinderbisunter6Jahre-insgesamt  Opfer-Kinderbisunter6Jahre-maennlich  \
# 0                                     3                                     1
# ...

# %%
df_combine=pd.concat([df_2014,df_2015,df_2016,df_2017,df_2018],ignore_index=True)
df_combine.to_csv("df.combine.csv",index=False)
print(df_combine.head(10))
print(df_combine.tail(10))
# Out:
#   SchluesselzahlderTat              Straftat  Gemeindeschlüssel  \
# 0               ------  Straftaten insgesamt          5334002.0
# 1               ------  Straftaten insgesamt          5334002.0
# 2               ------  Straftaten insgesamt          5334002.0
# 3               ------  Straftaten insgesamt          9761000.0
# 4               ------  Straftaten insgesamt          9761000.0
# 5               ------  Straftaten insgesamt          9761000.0
# 6               ------  Straftaten insgesamt          5378004.0
# 7               ------  Straftaten insgesamt          5378004.0
# 8               ------  Straftaten insgesamt          5378004.0
# 9               ------  Straftaten insgesamt         11000000.0
#
#                Stadt Fallstatus Opferinsgesamt-Anzahl  \
# 0             Aachen      voll.                  4033
# 1             Aachen      vers.                   327
# 2             Aachen      insg.                  4360
# ...

# %%
print(df_combine.columns)
# Out:
# Index(['SchluesselzahlderTat', 'Straftat', 'Gemeindeschlüssel', 'Stadt',
#        'Fallstatus', 'Opferinsgesamt-Anzahl', 'Opferinsgesamtmännlich-Anzahl',
#        'Opferinsgesamtweiblich-Anzahl', 'Kinderbisunter6Jahre-Anzahl',
#        'Kinderbisunter6Jahremännlich-Anzahl',
#        'Kinderbisunter6Jahreweiblich-Anzahl', 'Kinder6bisunter8JahreAnzahl',
#        'Kinder6bisunter8Jahremännlich-Anzahl',
#        'Kinder6bisunter8Jahreweiblich-Anzahl', 'Kinder8bisunter10Jahre-Anzahl',
#        'Kinder8bisunter10Jahremännlich-Anzahl',
#        'Kinder8bisunter10Jahreweiblich-Anzahl',
#        'Kinder10bisunter12Jahre-Anzahl',
#        'Kinder10bisunter12Jahremännlich-Anzahl',
#        'Kinder10bisunter12Jahreweiblich-Anzahl',
#        'Kinder12bisunter14Jahre-Anzahl',
#        'Kinder12bisunter14Jahremännlich-Anzahl',
#        'Kinder12bisunter14Jahreweiblich-Anzahl',
#        'Kinderbisunter14Jahreinsgesamt',
#        'Kinderbisunter14Jahreinsgesamtmännlich',
# ...

# %%
df_combined=pd.concat([df_2019,df_2020,df_2021,df_2022,df_2023],ignore_index=True)
df_combined.to_csv("df.combined.csv",index=False)
print(df_combined.head(10))
print(df_combined.tail(10))
# Out:
#   Schluessel              Straftat  Gemeindeschluessel              Stadt  \
# 0     ------  Straftaten insgesamt             5334002             Aachen
# 1     ------  Straftaten insgesamt             5334002             Aachen
# 2     ------  Straftaten insgesamt             5334002             Aachen
# 3     ------  Straftaten insgesamt             9761000           Augsburg
# 4     ------  Straftaten insgesamt             9761000           Augsburg
# 5     ------  Straftaten insgesamt             9761000           Augsburg
# 6     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 7     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 8     ------  Straftaten insgesamt             5378004  Bergisch Gladbach
# 9     ------  Straftaten insgesamt            11000000             Berlin
#
#   Fallstatus Operinsgesamt Opfermaennlich Opferweiblich  \
# 0      voll.         3,828          2,252         1,576
# ...

# %%
 # The number of columns is the second element in the shape tuple
print(f"Number of columns: {df_2014.shape[1]}")
print(f"Number of columns: {df_2015.shape[1]}")
print(f"Number of columns: {df_2016.shape[1]}")
print(f"Number of columns: {df_2017.shape[1]}")
print(f"Number of columns: {df_2018.shape[1]}")
# Out:
# Number of columns: 69
# Number of columns: 69
# Number of columns: 69
# Number of columns: 69
# Number of columns: 69

# %%
#rename columns
