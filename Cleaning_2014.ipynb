# %%
import pandas as pd

# %%
data_2014=pd.read_csv("Victims_2014.csv",encoding='ISO-8859-1', sep=';')

# %%
print(data_2014.head(10))
# Out:
#   Schluesselzahl der Tat              Straftat  Gemeindeschlüssel  \
# 0                 ------  Straftaten insgesamt            5334002
# 1                 ------  Straftaten insgesamt            5334002
# 2                 ------  Straftaten insgesamt            5334002
# 3                 ------  Straftaten insgesamt            9761000
# 4                 ------  Straftaten insgesamt            9761000
# 5                 ------  Straftaten insgesamt            9761000
# 6                 ------  Straftaten insgesamt            5378004
# 7                 ------  Straftaten insgesamt            5378004
# 8                 ------  Straftaten insgesamt            5378004
# 9                 ------  Straftaten insgesamt           11000000
#
#                Stadt Fallstatus  Opfer insgesamt - Anzahl  \
# 0             Aachen      voll.                      4033
# 1             Aachen      vers.                       327
# 2             Aachen      insg.                      4360
# ...

# %%
data_2014 = data_2014.rename(columns={'Schluesselzahl der Tat': 'Schluessel', 'Gemeindeschlüssel': 'Gemeindeschluessel'})
print(data_2014.head())
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#    Opfer insgesamt - Anzahl  Opfer insgesamt männlich- Anzahl  \
# 0                      4033                              2377
# 1                       327                               206
# 2                      4360                              2583
# 3                      4599                              2940
# 4                       544                               410
#
#    Opfer insgesamt weiblich- Anzahl  Kinder bis unter 6 Jahre - Anzahl  \
# ...

# %%
data_2014 = data_2014.rename(columns={'Opfer insgesamt - Anzahl': 'Oper insgesamt', 'Opfer insgesamt männlich- Anzahl': 'Opfer männlich', "Opfer insgesamt weiblich- Anzahl":"Opfer weiblich","Kinder bis unter 6 Jahre - Anzahl":"Opfer - Kinder bis unter 6 Jahre - insgesamt","Kinder bis unter 6 Jahre männlich- Anzahl":"Opfer - Kinder bis unter 6 Jahre - männlich","Kinder bis unter 6 Jahre weiblich - Anzahl":"Opfer - Kinder bis unter 6 Jahre - weiblich","Kinder bis unter 14 Jahre insgesamt":"Opfer Kinder bis 14 Jahre- insgesamt","Kinder bis unter 14 Jahre insgesamt männlich":"Opfer Kinder bis 14 Jahre- männlich","Kinder bis unter 14 Jahre insgesamt weiblich":"Opfer Kinder bis 14 Jahre- weiblich","Jugendliche 14 bis unter 18 Jahre insgesamt":"Opfer Jugendliche 14 bis unter 18 Jahre - insgesamt","Jugendliche 14 bis unter 18 Jahre insgesamt - männlich":"Opfer Jugendliche 14 bis unter 18 Jahre - männlich","Jugendliche 14 bis unter 18 Jahre insgesamt - weiblich":"Opfer Jugendliche 14 bis unter 18 Jahre - weiblich","Heranwachsende 18 bis unter 21 Jahre - Anzahl":"Opfer - Heranwachsende 18 bis unter 21 Jahre - insgesamt","Heranwachsende 18 bis unter 21 Jahre männlich - Anzahl":"Opfer - Heranwachsende 18 bis unter 21 Jahre - männlich","Heranwachsende 18 bis unter 21 Jahre weiblich - Anzahl":"Opfer - Heranwachsende 18 bis unter 21 Jahre - weiblich","Erwachsene 60 Jahre und aelter":"Opfer - Erwachsene 60 Jahre und aelter - insgesamt","Erwachsene 60 Jahre und aelter - männlich":"Opfer - Erwachsene 60 Jahre und aelter - männlich","Erwachsene 60 Jahre und aelter - weiblich":"Opfer - Erwachsene 60 Jahre und aelter - weiblich","Erwachsene ab 21 Jahre":"Opfer Erwachsene - insgesamt","Erwachsene ab 21 Jahre - männlich":"Opfer Erwachsene - männlich","Erwachsene ab 21 Jahre - weiblich":"Opfer Erwachsene - weiblich"})

# %%
print(len(data_2014.columns))
print(data_2014.head())
# Out:
# 68
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#    Oper insgesamt  Opfer männlich  Opfer weiblich  \
# 0            4033            2377            1656
# 1             327             206             121
# 2            4360            2583            1777
# 3            4599            2940            1659
# 4             544             410             134
#
#    Opfer - Kinder bis unter 6 Jahre - insgesamt  \
# 0                                            15
# 1                                             3
# 2                                            18
# ...

# %%
print(data_2014.columns)
data_2014 = data_2014.replace('männlich', 'maennlich')
# Out:
# Index(['Schluessel', 'Straftat', 'Gemeindeschluessel', 'Stadt', 'Fallstatus',
#        'Oper insgesamt', 'Opfer männlich', 'Opfer weiblich',
#        'Opfer - Kinder bis unter 6 Jahre - insgesamt',
#        'Opfer - Kinder bis unter 6 Jahre - männlich',
#        'Opfer - Kinder bis unter 6 Jahre - weiblich',
#        'Kinder 6 bis unter 8 Jahre Anzahl',
#        'Kinder 6 bis unter 8 Jahre männlich - Anzahl',
#        'Kinder 6 bis unter 8 Jahre weiblich - Anzahl',
#        'Kinder 8 bis unter 10 Jahre - Anzahl',
#        'Kinder 8 bis unter 10 Jahre männlich - Anzahl',
#        'Kinder 8 bis unter 10 Jahre weiblich - Anzahl',
#        'Kinder 10 bis unter 12 Jahre - Anzahl',
#        'Kinder 10 bis unter 12 Jahre männlich- Anzahl',
#        'Kinder 10 bis unter 12 Jahre weiblich - Anzahl',
#        'Kinder 12 bis unter 14 Jahre - Anzahl',
#        'Kinder 12 bis unter 14 Jahre männlich - Anzahl',
#        'Kinder 12 bis unter 14 Jahre weiblich - Anzahl',
# ...

# %%
data_2014.columns = data_2014.columns.str.replace('männlich', 'maennlich')

# %%
print(data_2014.columns)
# Out:
# Index(['Schluessel', 'Straftat', 'Gemeindeschluessel', 'Stadt', 'Fallstatus',
#        'Oper insgesamt', 'Opfer maennlich', 'Opfer weiblich',
#        'Opfer - Kinder bis unter 6 Jahre - insgesamt',
#        'Opfer - Kinder bis unter 6 Jahre - maennlich',
#        'Opfer - Kinder bis unter 6 Jahre - weiblich',
#        'Kinder 6 bis unter 8 Jahre Anzahl',
#        'Kinder 6 bis unter 8 Jahre maennlich - Anzahl',
#        'Kinder 6 bis unter 8 Jahre weiblich - Anzahl',
#        'Kinder 8 bis unter 10 Jahre - Anzahl',
#        'Kinder 8 bis unter 10 Jahre maennlich - Anzahl',
#        'Kinder 8 bis unter 10 Jahre weiblich - Anzahl',
#        'Kinder 10 bis unter 12 Jahre - Anzahl',
#        'Kinder 10 bis unter 12 Jahre maennlich- Anzahl',
#        'Kinder 10 bis unter 12 Jahre weiblich - Anzahl',
#        'Kinder 12 bis unter 14 Jahre - Anzahl',
#        'Kinder 12 bis unter 14 Jahre maennlich - Anzahl',
#        'Kinder 12 bis unter 14 Jahre weiblich - Anzahl',
# ...

# %%
data_2014["Jahr"]=2014
print(data_2014.head())
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#    Oper insgesamt  Opfer maennlich  Opfer weiblich  \
# 0            4033             2377            1656
# 1             327              206             121
# 2            4360             2583            1777
# 3            4599             2940            1659
# 4             544              410             134
#
#    Opfer - Kinder bis unter 6 Jahre - insgesamt  \
# 0                                            15
# 1                                             3
# 2                                            18
# ...

# %%
#create a new column 
data_2014["Opfer Kinder 6 bis unter 14 Jahre - insgesamt"]=(
    data_2014["Kinder 6 bis unter 8 Jahre Anzahl"] +
    data_2014["Kinder 8 bis unter 10 Jahre - Anzahl"] +
    data_2014["Kinder 10 bis unter 12 Jahre - Anzahl"] +
    data_2014["Kinder 12 bis unter 14 Jahre - Anzahl"])

# %%
print(data_2014["Opfer Kinder 6 bis unter 14 Jahre - insgesamt"])
# Out:
# 0       117
# 1        13
# 2       130
# 3       227
# 4        15
#        ...
# 3415      0
# 3416      0
# 3417      0
# 3418      0
# 3419      0
# Name: Opfer Kinder 6 bis unter 14 Jahre - insgesamt, Length: 3420, dtype: int64

# %%
data_2014["Opfer Kinder 6  bis unter 14 Jahre - maennlich"]=(
    data_2014["Kinder 6 bis unter 8 Jahre maennlich - Anzahl"] +
    data_2014["Kinder 8 bis unter 10 Jahre maennlich - Anzahl"] +
    data_2014["Kinder 10 bis unter 12 Jahre maennlich- Anzahl"] +
    data_2014["Kinder 12 bis unter 14 Jahre maennlich - Anzahl"])

# %%
print(data_2014["Opfer Kinder 6  bis unter 14 Jahre - maennlich"])
# Out:
# 0        72
# 1         6
# 2        78
# 3       117
# 4        12
#        ...
# 3415      0
# 3416      0
# 3417      0
# 3418      0
# 3419      0
# Name: Opfer Kinder 6  bis unter 14 Jahre - maennlich, Length: 3420, dtype: int64

# %%
data_2014["Opfer Kinder 6  bis unter 14 Jahre - weiblich"]=(
    data_2014["Kinder 6 bis unter 8 Jahre weiblich - Anzahl"] +
    data_2014["Kinder 8 bis unter 10 Jahre weiblich - Anzahl"] +
    data_2014["Kinder 10 bis unter 12 Jahre weiblich - Anzahl"] +
    data_2014["Kinder 12 bis unter 14 Jahre weiblich - Anzahl"])

# %%
print(data_2014["Opfer Kinder 6  bis unter 14 Jahre - weiblich"])
# Out:
# 0        45
# 1         7
# 2        52
# 3       110
# 4         3
#        ...
# 3415      0
# 3416      0
# 3417      0
# 3418      0
# 3419      0
# Name: Opfer Kinder 6  bis unter 14 Jahre - weiblich, Length: 3420, dtype: int64

# %%
data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - insgesamt"]=(
    data_2014["Erwachsene 21 bis unter 25 Jahre"] +
    data_2014["Erwachsene 25 bis unter 30 Jahre"] +
    data_2014["Erwachsene 30 bis unter 40 Jahre"] +
    data_2014["Erwachsene 40 bis unter 50 Jahre"] +
    data_2014["Erwachsene 50 bis unter 60 Jahre"] )

print(data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - insgesamt"])
# Out:
# 0       2955
# 1        230
# 2       3185
# 3       3315
# 4        442
#         ...
# 3415       4
# 3416       5
# 3417       1
# 3418       1
# 3419       2
# Name: Opfer Erwachsene 21 bis unter 60 Jahre - insgesamt, Length: 3420, dtype: int64

# %%
data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - maennlich"]=(
    data_2014["Erwachsene 21 bis unter 25 Jahre - maennlich"] +
    data_2014["Erwachsene 25 bis unter 30 Jahre - maennlich"] +
    data_2014["Erwachsene 30 bis unter 40 Jahre - maennlich"] +
    data_2014["Erwachsene 40 bis unter 50 Jahre - maennlich"] +
    data_2014["Erwachsene 50 bis unter 60 Jahre - maennlich"] )

print(data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - maennlich"])
# Out:
# 0       1756
# 1        153
# 2       1909
# 3       2181
# 4        336
#         ...
# 3415       4
# 3416       4
# 3417       0
# 3418       1
# 3419       1
# Name: Opfer Erwachsene 21 bis unter 60 Jahre - maennlich, Length: 3420, dtype: int64

# %%
data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - weiblich"]=(
    data_2014["Erwachsene 21 bis unter 25 Jahre - weiblich"] +
    data_2014["Erwachsene 25 bis unter 30 Jahre - weiblich"] +
    data_2014["Erwachsene 30 bis unter 40 Jahre - weiblich"] +
    data_2014["Erwachsene 40 bis unter 50 Jahre - weiblich"] +
    data_2014["Erwachsene 50 bis unter 60 Jahre - weiblich"] )

print(data_2014["Opfer Erwachsene 21 bis unter 60 Jahre - weiblich"])
# Out:
# 0       1199
# 1         77
# 2       1276
# 3       1134
# 4        106
#         ...
# 3415       0
# 3416       1
# 3417       1
# 3418       0
# 3419       1
# Name: Opfer Erwachsene 21 bis unter 60 Jahre - weiblich, Length: 3420, dtype: int64

# %%
data_2014.to_csv("data_2024.csv",index=False)

# %%
print(data_2014.head())
# Out:
#   Schluessel              Straftat  Gemeindeschluessel     Stadt Fallstatus  \
# 0     ------  Straftaten insgesamt             5334002    Aachen      voll.
# 1     ------  Straftaten insgesamt             5334002    Aachen      vers.
# 2     ------  Straftaten insgesamt             5334002    Aachen      insg.
# 3     ------  Straftaten insgesamt             9761000  Augsburg      voll.
# 4     ------  Straftaten insgesamt             9761000  Augsburg      vers.
#
#    Oper insgesamt  Opfer maennlich  Opfer weiblich  \
# 0            4033             2377            1656
# 1             327              206             121
# 2            4360             2583            1777
# 3            4599             2940            1659
# 4             544              410             134
#
#    Opfer - Kinder bis unter 6 Jahre - insgesamt  \
# 0                                            15
# 1                                             3
# 2                                            18
# ...

# %%
data_2014.drop(columns=["Kinder 6 bis unter 8 Jahre Anzahl","Kinder 6 bis unter 8 Jahre maennlich - Anzahl","Kinder 6 bis unter 8 Jahre weiblich - Anzahl","Kinder 8 bis unter 10 Jahre - Anzahl","Kinder 8 bis unter 10 Jahre maennlich - Anzahl","Kinder 8 bis unter 10 Jahre weiblich - Anzahl","Kinder 10 bis unter 12 Jahre - Anzahl","Kinder 10 bis unter 12 Jahre maennlich- Anzahl","Kinder 10 bis unter 12 Jahre weiblich - Anzahl","Kinder 12 bis unter 14 Jahre - Anzahl","Kinder 12 bis unter 14 Jahre maennlich - Anzahl","Kinder 12 bis unter 14 Jahre weiblich - Anzahl","Jugendliche 14 bis unter 16 Jahre - Anzahl","Jugendliche 14 bis unter 16 Jahre maennlich - Anzahl","Jugendliche 14 bis unter 16 Jahre weiblich - Anzahl","Jugendliche 16 bis unter 18 Jahre - Anzahl","Jugendliche 16 bis unter 18 Jahre maennlich - Anzahl","Jugendliche 16 bis unter 18 Jahre weiblich - Anzahl","Opfer insgesamt unter 21 Jahre","Opfer insgesamt unter 21 Jahre - maennlich","Opfer insgesamt unter 21 Jahre - weiblich","Erwachsene 23 bis unter 25 Jahre - Anzahl","Erwachsene 23 bis unter 25 Jahre maennlich- Anzahl","Erwachsene 23 bis unter 25 Jahre weiblich - Anzahl","Erwachsene 23 bis unter 25 Jahre weiblich - Anzahl","Erwachsene 21 bis unter 25 Jahre","Erwachsene 21 bis unter 25 Jahre - maennlich","Erwachsene 21 bis unter 25 Jahre - weiblich","Erwachsene 25 bis unter 30 Jahre","Erwachsene 25 bis unter 30 Jahre - maennlich","Erwachsene 25 bis unter 30 Jahre - weiblich","Erwachsene 30 bis unter 40 Jahre","Erwachsene 30 bis unter 40 Jahre - maennlich","Erwachsene 30 bis unter 40 Jahre - weiblich","Erwachsene 40 bis unter 50 Jahre","Erwachsene 40 bis unter 50 Jahre - maennlich","Erwachsene 40 bis unter 50 Jahre - weiblich","Erwachsene 50 bis unter 60 Jahre","Erwachsene 50 bis unter 60 Jahre - maennlich","Erwachsene 50 bis unter 60 Jahre - weiblich","Erwachsene 21 bis unter 23 Jahre - Anzahl","Erwachsene 21 bis unter 23 Jahre maennlich - Anzahl","Erwachsene 21 bis unter 23 Jahre weiblich - Anzahl"], inplace=True)

# %%
data_2014.to_csv("data_2024.csv",index=False)

# %%
print(len(data_2014.columns))
# Out:
# 33

# %%
new_column_order = [
    'Schluessel',
    'Straftat',
    'Gemeindeschluessel',
    'Stadt',
    'Fallstatus',
    'Oper insgesamt',
    'Opfer maennlich',
    'Opfer weiblich',
    'Opfer - Kinder bis unter 6 Jahre - insgesamt',
    'Opfer - Kinder bis unter 6 Jahre - maennlich',
    'Opfer - Kinder bis unter 6 Jahre - weiblich',
    'Opfer Kinder 6 bis unter 14 Jahre - insgesamt',
    'Opfer Kinder 6  bis unter 14 Jahre - maennlich',
    'Opfer Kinder 6  bis unter 14 Jahre - weiblich',
    'Opfer Kinder bis 14 Jahre- insgesamt',
    'Opfer Kinder bis 14 Jahre- maennlich',
    'Opfer Kinder bis 14 Jahre- weiblich',
    'Opfer Jugendliche 14 bis unter 18 Jahre - insgesamt',
    'Opfer Jugendliche 14 bis unter 18 Jahre - maennlich',
    'Opfer Jugendliche 14 bis unter 18 Jahre - weiblich',
    'Opfer - Heranwachsende 18 bis unter 21 Jahre - insgesamt',
    'Opfer - Heranwachsende 18 bis unter 21 Jahre - maennlich',
    'Opfer - Heranwachsende 18 bis unter 21 Jahre - weiblich',
    'Opfer Erwachsene 21 bis unter 60 Jahre - insgesamt',
    'Opfer Erwachsene 21 bis unter 60 Jahre - maennlich',
    'Opfer Erwachsene 21 bis unter 60 Jahre - weiblich',
    'Opfer - Erwachsene 60 Jahre und aelter - insgesamt',
    'Opfer - Erwachsene 60 Jahre und aelter - maennlich',
    'Opfer - Erwachsene 60 Jahre und aelter - weiblich',
    'Opfer Erwachsene - insgesamt',
    'Opfer Erwachsene - maennlich',
    'Opfer Erwachsene - weiblich',
    'Jahr'
]

# %%
data_2014=data_2014[new_column_order]

# %%
data_2014.to_csv("data_2024.csv",index=False)

# %%
data_2014.columns = data_2014.columns.str.replace(' ', '_', regex=False)

# %%
print(data_2014.columns)
# Out:
# Index(['Schluessel', 'Straftat', 'Gemeindeschluessel', 'Stadt', 'Fallstatus',
#        'Oper_insgesamt', 'Opfer_maennlich', 'Opfer_weiblich',
#        'Opfer_-_Kinder_bis_unter_6_Jahre_-_insgesamt',
#        'Opfer_-_Kinder_bis_unter_6_Jahre_-_maennlich',
#        'Opfer_-_Kinder_bis_unter_6_Jahre_-_weiblich',
#        'Opfer_Kinder_6_bis_unter_14_Jahre_-_insgesamt',
#        'Opfer_Kinder_6__bis_unter_14_Jahre_-_maennlich',
#        'Opfer_Kinder_6__bis_unter_14_Jahre_-_weiblich',
#        'Opfer_Kinder_bis_14_Jahre-_insgesamt',
#        'Opfer_Kinder_bis_14_Jahre-_maennlich',
#        'Opfer_Kinder_bis_14_Jahre-_weiblich',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre_-_insgesamt',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre_-_maennlich',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre_-_weiblich',
#        'Opfer_-_Heranwachsende_18_bis_unter_21_Jahre_-_insgesamt',
#        'Opfer_-_Heranwachsende_18_bis_unter_21_Jahre_-_maennlich',
# ...

# %%
data_2014.columns = data_2014.columns.str.replace('-', '', regex=False)

# %%
print(data_2014.columns)
# Out:
# Index(['Schluessel', 'Straftat', 'Gemeindeschluessel', 'Stadt', 'Fallstatus',
#        'Oper_insgesamt', 'Opfer_maennlich', 'Opfer_weiblich',
#        'Opfer__Kinder_bis_unter_6_Jahre__insgesamt',
#        'Opfer__Kinder_bis_unter_6_Jahre__maennlich',
#        'Opfer__Kinder_bis_unter_6_Jahre__weiblich',
#        'Opfer_Kinder_6_bis_unter_14_Jahre__insgesamt',
#        'Opfer_Kinder_6__bis_unter_14_Jahre__maennlich',
#        'Opfer_Kinder_6__bis_unter_14_Jahre__weiblich',
#        'Opfer_Kinder_bis_14_Jahre_insgesamt',
#        'Opfer_Kinder_bis_14_Jahre_maennlich',
#        'Opfer_Kinder_bis_14_Jahre_weiblich',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre__insgesamt',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre__maennlich',
#        'Opfer_Jugendliche_14_bis_unter_18_Jahre__weiblich',
#        'Opfer__Heranwachsende_18_bis_unter_21_Jahre__insgesamt',
#        'Opfer__Heranwachsende_18_bis_unter_21_Jahre__maennlich',
# ...
